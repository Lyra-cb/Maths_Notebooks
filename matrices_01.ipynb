# %%
import numpy as np

# %%
A = np.array([[1, 2],
              [3, 4]])

B = np.array([[5, 6],
              [7, 8]])

print("Matrix A:")
print(A)
print("\nMatrix B:")
print(B)
# Out:
# Matrix A:
# [[1 2]
#  [3 4]]
#
# Matrix B:
# [[5 6]
#  [7 8]]

# %%
print("Shape of A:", A.shape)
print("Shape of B:", B.shape)
# Out:
# Shape of A: (2, 2)
# Shape of B: (2, 2)

# %%
result = np.dot(A, B)
print("A × B =")
print(result)
# Out:
# A × B =
# [[19 22]
#  [43 50]]

# %%
# A non-square example
C = np.array([[1, 2, 3],
              [4, 5, 6]])   # 2x3

D = np.array([[7,  8],
              [9,  10],
              [11, 12]])    # 3x2

result2 = np.dot(C, D)
print("Shape of C:", C.shape)
print("Shape of D:", D.shape)
print("Result shape:", result2.shape)
print(result2)
# Out:
# Shape of C: (2, 3)
# Shape of D: (3, 2)
# Result shape: (2, 2)
# [[ 58  64]
#  [139 154]]

# %%
# 3 patients, each with 3 risk factors (age_scaled, sbp_scaled, smoking)
patients = np.array([[0.8, 1.2, 1.0],
                     [0.5, 0.9, 0.0],
                     [1.1, 1.4, 1.0]])

# Coefficients for each risk factor
coefficients = np.array([0.5, 0.3, 0.8])

# One matrix multiplication → risk scores for ALL patients simultaneously
risk_scores = np.dot(patients, coefficients)
print("Risk scores:", risk_scores)
# Out:
# Risk scores: [1.56 0.52 1.77]
